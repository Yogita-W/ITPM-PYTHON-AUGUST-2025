# %% [markdown]
# Types of Error:1.Compile Time
#                        1.Syntax Error 2.Indent
#                2.Run-time Error

# %%
print('Hello)
print('Well-come')
# Out:
#   Cell In[1], line 1
#     print('Hello)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x = 4
name = 'abcd'
print(X)
print(name
# Out:
#   Cell In[3], line 4
#     print(name
#               ^
# SyntaxError: incomplete input

# %%
for i in range(1,10):
# Out:
#   Cell In[12], line 2
#     {
#     ^
# IndentationError: expected an indented block after 'for' statement on line 1

# %% [markdown]
# 2.Run-time Errors

# %%
#NameError
= 'Rajas'
print(name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 Name = 'Rajas'
# ----> 2 print(name)
#
# NameError: name 'name' is not defined

# %%
#2.TypeError
x = 12
y = '30'
z = x+y
print(z)
# Out:
# 42

# %%
#ZeroDivisionError 
x = int(input("Enter a number"))
y = int(input("Enter a number"))
z = x/y
print(z) 
print("WEell-come")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 x = int(input("Enter a number"))
#       2 y = int(input("Enter a number"))
# ----> 3 z = x/y
#       4 print(z)
#       5 print("WEell-come")
#
# ZeroDivisionError: division by zero

# %%
#IndexError
list1 = [1,23,4,5,7,8,8]
list1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 list1 = [1,23,4,5,7,8,8]
# ----> 2 list1[10]
#
# IndexError: list index out of range

# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#without Using EH
x = int(input("Enter a number"))
y = int(input("Enter a number"))
z = x/y
print(z)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[32], line 4
#       2 x = int(input("Enter a number"))
#       3 y = int(input("Enter a number"))
# ----> 4 z = x/y
#       5 print(z)
#
# ZeroDivisionError: division by zero

# %%
#using Exception Handling
try:
    x = int(input("Enter a number"))
    y = int(input("Enter a number"))
    z = x/y
    print(z) 
except ZeroDivisionError:
    print(f"you have enter y = {y} which is not correct plz enter a valid value ")
    
finally:   
    print("Well-come")
# Out:
# you have enter y = 0 which is not correct plz enter a valid value
# WEell-come

# %%
print(Y1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 print(Y1)
#
# NameError: name 'Y1' is not defined

# %%
Name = 'Urvashi'
print(Name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 Name = 'Urvashi'
# ----> 2 print(name)
#
# NameError: name 'name' is not defined

# %%
x = int(input("Enter a number"))
print(x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 x = int(input("Enter a number"))
#       2 print(x)
#
# ValueError: invalid literal for int() with base 10: '10.56'

# %%
try :
    x = int(input("Enter a number")) # 100 ,145.76
except ValueError :
    print( "Plz Enter Int Value") # 
else:
    print(x)
finally :
    print("Thank you......")
# Out:
# Plz Enter Int Value
# Thank you......

# %%
try : 
     x = int(input("enter a number"))
     y = int(input("enter a number"))
     z = x+y
except ValueError  :
    print("Plz Enter a Correct Data Type to perform addition")  
else :
    print(z)
finally :
    print("Thank you........")
# Out:
# Plz Enter a Correct Data Type to perform addition
# Thank you........

# %%
Age = int(input("Enter your age"))
if Age >= 21:
    print("Your Eligible forVoting")
else :
    print("Your not Eligible for Voting")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 Age = int(input("Enter your age"))
#       2 if Age >= 21:
#       3     print("Your Eligible forVoting")
#
# ValueError: invalid literal for int() with base 10: '23.5'

# %%
try :
    Age = int(input("Enter your age"))
    if Age >= 21:
         print("Your Eligible forVoting")
    else :
        print("Your not Eligible for Voting")  
except ValueError :
    print("Plz Enter a age in the formate of int")  
else :
    print(f"because Your Age is {Age}")
# Out:
# Plz Enter a age in the formate of int

# %% [markdown]
# Exceptions in Ds;

# %%
list1 = [1,2,3,4,5,6,7,8]
list1[10]
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.11.9' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
lis

# %%
try:
    list1 = [1,2,3,4,5,6,7,8]
    x = int(input("Enter index number"))
    l10 = list1[x]
except IndexError :
    print("Enter index between 0 to 7 ")
else :
    print(l10)  
finally :
    print("Keep Practicing")
# Out:
# 6
# Keep Practicing

# %%
try:
    list1 = [1,2,3,4,5,6,7,8]
    x = int(input("Enter index number"))
    l10 = list1[x]
except IndexError :
    print(f" IE :Enter index between 0 to 7 ")
except ValueError :
    print("plz enter index in int formate")    
else :
    print(l10)  
finally :
    print("Keep Practicing")
# Out:
# plz enter index in int formate
# Keep Practicing

# %%
t1 = (1,2,3,4,5,6,7)
t1.append(8)
print(t1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 t1 = (1,2,3,4,5,6,7)
# ----> 2 t1.append(8)
#       3 print(t1)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
try :
    t1 = (1,2,3,4,5)
    t1.append(6)
except AttributeError :
    print("Tuple is immutable in nature")  
else :
    print(t1)
# Out:
# Tuple is immutable in nature

# %%
dict1 = {101:[12,32,44,54,65],
         'subject':['python','UI','Apti']}
dict1['Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 3
#       1 dict1 = {101:[12,32,44,54,65],
#       2          'subject':['python','UI','Apti']}
# ----> 3 dict1['Name']
#
# KeyError: 'Name'

# %%
try : 
    dict1 = dict1 = {101:[12,32,44,54,65],
         'subject':['python','UI','Apti']}
    key = input("Enter a key")
    dict1[key]
except KeyError :
    print("plz Enter a valid key")  
else :
    print(dict1[key]) 
finally :
    print(".............................")
# Out:
# plz Enter a valid key
# ..........................................................................

# %%
l1 = [1,2,3,4,5]
print([1,2,3] in l1)
# Out:
# False

# %%
l1 = [1,2,3,4]
l2 = [5,6,7,8,9]
print(l1/l2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 l1 = [1,2,3,4]
#       2 l2 = [5,6,7,8,9]
# ----> 3 print(l1/l2)
#
# TypeError: unsupported operand type(s) for /: 'list' and 'list'

# %%
try:
    l1 = [1,2,3,4]
    l2 = [5,6,7,8,9]
    print(l1/l2)
except TypeError :
    print("plz Enter a valid operator")
else :
    print(l1/l2)
# Out:
# plz Enter a valid operator

# %%
try :
     str1 = 'yogita'
     print(str1
except SyntaxError :
    print("Syntax Error")
else :
    print(str1)
# Out:
#   Cell In[22], line 3
#     print(str1
#          ^
# SyntaxError: '(' was never closed

# %%
def add(x,y):
return x+y
add(10,20)
# Out:
#   Cell In[25], line 2
#     return x+y
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
try :
    def add(x,y):
    return x+y
    add(10,20)
except IndentationError :
    print("Add Space")
# Out:
#   Cell In[26], line 3
#     return x+y
#     ^
# IndentationError: expected an indented block after function definition on line 2

# %%
def math(n):
    return n
math(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 3
#       1 def math(n):
#       2     return n
# ----> 3 math(10,20)
#
# TypeError: math() takes 1 positional argument but 2 were given

# %%
try : 
    def math(num):
        return num
except TypeError :
    print("Enter a 1 parameter only")  
except ValueError :
    print("Enter int value only")     
else :
    print(math(num = int(input("Enter a number"))))
# Out:
# 12

# %%
#Ex: for loop exception
for i in range:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 #Ex: for loop exception
# ----> 2 for i in range:
#       3     print(i)
#
# TypeError: 'type' object is not iterable

# %%
try : 
    for i in range:
        print(i)
except TypeError :
    print("Enter a valid type")
# Out:
# Enter a valid type

# %%
str1 = input("Enter a string")
str2 = input("Enter second String")
if str1 == str3[::-1] :
    print("Palimdrom String")
else :
    print(" Not Palimdrom String")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 str1 = input("Enter a string")
#       2 str2 = input("Enter second String")
# ----> 3 if str1 == str3[::-1] :
#       4     print("Palimdrom String")
#       5 else :
#
# NameError: name 'str3' is not defined

# %%
class number:
    def n1(self,n):
        return 
obj1 = number()  
print(obj1.n1(2))
# Out:
# None

# %%
try :
    class number:
        def n1(self,n):
           return 
    obj1 = number()  
    print(Obj1.n1(2))   
except NameError :
    print("Enter a valid variable name")
else:    
    print("........")
# Out:
# Enter a valid variable name

# %%
try :
    l2 = [23,43,54,32]
    l2[10]
    l1 = [1,2,3,4,5]
    l1[6]
except IndexError :
    print("Enter a valid Index")
else :
    print(l2[10],l1[6])
finally :
    print("Thank you..............")
# Out:
# Enter a valid Index
# Thank you..............
